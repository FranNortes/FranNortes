# %% [markdown]
# <a href="https://colab.research.google.com/github/FranNortes/FranNortes/blob/main/K_POP_Desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Póster Festival Kpop Moderno Morado y Rosa.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# En los últimos años, el K-POP ha evolucionado de ser un fenómeno cultural coreano a convertirse en una industria global multimillonaria. Grupos como **BTS**, **BLACKPINK** y **EXO** han demostrado que el impacto del K-POP trasciende fronteras, conquistando mercados clave como Estados Unidos, Europa y América Latina. </br> Este éxito se basa en estrategias únicas que combinan talento, conceptos innovadores y una conexión profunda con los fans a través de redes sociales y plataformas digitales.

# %% [markdown]
# Como analista de datos de una discográfica española, nuestra misión es identificar nuevas oportunidades para crear un festival en españa y dar a conocer este estilo musical. <br/> <br/> **Como objetivos de la presentación tenemos:** <br/><br/>
# - Comprender las claves del éxito de los grupos de K-POP más influyentes.<br/>
# *Identificar nuevos grupos emergentes que comparten características similares a los líderes históricos.
# +Proponer estrategias de inversión basadas en datos para maximizar el retorno y posicionar a nuestra discográfica en este mercado.

# %% [markdown]
# # Codigo Python

# %% [markdown]
# Importamos las librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importar lector de tablas
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cargamos las tablas
Kpop_idols = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Desafio Pontia/DataSets K-pop Challenge/kpop_idols.csv")
Kpop_idols_boys = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Desafio Pontia/DataSets K-pop Challenge/kpop_idols_boy_groups.csv")
Kpop_idols_girls = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Desafio Pontia/DataSets K-pop Challenge/kpop_idols_girl_groups.csv")
Kpop_music_videos = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Desafio Pontia/DataSets K-pop Challenge/kpop_music_videos.csv")

# %% [markdown]
# Este informe presenta un análisis exploratorio detallado de los datos relacionados con la industria del K-pop, basado en cuatro conjuntos de datos principales: Kpop_idols, Kpop_idols_boys, Kpop_idols_girls y Kpop_music_videos.

# %%
#Analisis rapido de tablas
print('---------Kpop_idols--------')
print(Kpop_idols)
print('---------Kpop_idols_boys--------')
print(Kpop_idols_boys)
print('---------Kpop_idols_girls--------')
print(Kpop_idols_girls)
print('---------Kpop_music_videos--------')
print(Kpop_music_videos)
# Out:
# ---------Kpop_idols--------
#      Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0           A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1           Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2          Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3          AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4          Ahra        Go Ahra         고아라            아라    2001-02-21
# ...         ...            ...         ...           ...           ...
# 1305        Ziu    Park Heejun         박희준            지우    1997-06-16
# 1306         ZN      Bae Jinye         배진예            지엔    1994-06-09
# 1307        Zoa     Cho Hyewon         조혜원            조아    2005-05-31
# 1308       Zuho       Bae Juho         백주호            주호    1996-07-04
# 1309       Zuny      Kim Joomi         김주미            주니    1994-12-08
#
#              Group      Country Birthplace Other Group Gender
# ...

# %% [markdown]
# **Kpop_idols** </br>
#
# Esta tabla contiene información detallada sobre ídolos del K-pop individuales:
#
#
# *   Columnas: 10
# *   Filas: 1310

# %%
# Mostramos las tablas
print('---------Kpop_idols--------')
Kpop_idols.head()
# Out:
# ---------Kpop_idols--------
#   Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0        A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1        Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2       Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3       AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4       Ahra        Go Ahra         고아라            아라    2001-02-21
#
#        Group      Country Birthplace Other Group Gender
# 0  Limitless  South Korea        NaN         NaN      M
# 1        VAV  South Korea        NaN         NaN      M
# 2    Hashtag  South Korea      Daegu         NaN      F
# 3   MOMOLAND  South Korea      Wonju         NaN      F
# 4   Favorite  South Korea      Yeosu         NaN      F

# %% [markdown]
# **Kpop_idols_boys** </br>
# Información específica sobre grupos de chicos:
# *   Columans: 9
# *   Filas: 147

# %%
print('---------Kpop_idols_boys--------')
Kpop_idols_boys
# Out:
# ---------Kpop_idols_boys--------
#                Name Short Korean Name       Debut       Company  Members  \
# 0              100%   NaN        백퍼센트  2012-09-18     TOP Media        4
# 1               14U   NaN         원포유  2017-04-17            BG       14
# 2             1the9   NaN        원더나인  2019-02-09           MBK        9
# 3               24K   NaN        투포케이  2012-09-06        Choeun        8
# 4               2AM   NaN        투에이엠  2008-06-21  JYP, Big Hit        4
# ..              ...   ...         ...         ...           ...      ...
# 142        VROMANCE   NaN        브로맨스  2016-06-12           RBW        4
# 143       Wanna One   NaN         워너원  2017-08-07           YMC       11
# 144  We In The Zone   NaN        위인더존  2019-05-27         Choon        5
# 145          WINNER   NaN          위너  2014-08-12            YG        4
# 146            ZE:A   NaN     제국의 아이들  2010-01-07   Star Empire        9
#
#      Orig. Memb. Fanclub Name  Active
# ...

# %% [markdown]
# **Kpop_idols_girls** </br>
# Datos sobre grupos de chicas:
# *   Columnas: 9
# *   Filas: 152

# %%
print('---------Kpop_idols_girls--------')
Kpop_idols_girls
# Out:
# ---------Kpop_idols_girls--------
#              Name         Short Korean Name       Debut    Company  Members  \
# 0        (G)I-DLE           NaN     (여자)아이들  2018-05-02       Cube        6
# 1             15&           NaN       피프틴앤드  2012-10-05        JYP        2
# 2           2EYES           NaN        투아이즈  2013-07-20    SidusHQ        4
# 3            2NE1           NaN        투애니원  2009-05-06         YG        4
# 4             3YE           NaN        써드아이  2019-05-21         GH        3
# ..            ...           ...         ...         ...        ...      ...
# 147      We Girls           NaN         위걸스  2018-08-31  Afternoon        8
# 148     Weki Meki          WeMe        위키미키  2017-08-08   Fantagio        8
# 149          WJSN  Cosmic Girls        우주소녀  2016-02-25   Starship       13
# 150  Wonder Girls            WG        원더걸스  2007-02-13        JYP        4
# 151    Yellow Bee           NaN         옐로비  2017-11-23  Addiction        5
#
# ...

# %% [markdown]
# **Kpop_music_videos** </br>
# Información sobre videos musicales de K-pop:
#
# *   Columnas: 8
# *   Filas: 3772

# %%
print('---------Kpop_music_videos--------')
Kpop_music_videos
# Out:
# ---------Kpop_music_videos--------
#             Date              Artist                      Song Name  \
# 0     2020-05-22             Agust D                      Daechwita
# 1     2020-05-21               Yubin                 yaya (Me Time)
# 2     2020-05-21           OnlyOneOf             Angel (prod. GRAY)
# 3     2020-05-20         Ryu Sujeong                     Tiger Eyes
# 4     2020-05-20               Crush  Mayday feat. Joy (Red Velvet)
# ...          ...                 ...                            ...
# 3767  1994-08-08  Seo Taiji and Boys                       Eternity
# 3768  1993-06-06  Seo Taiji and Boys                    Anyhow Song
# 3769  1993-06-06  Seo Taiji and Boys                         To You
# 3770  1992-03-23  Seo Taiji and Boys                         I Know
# 3771  1992-03-23  Seo Taiji and Boys            You, In The Fantasy
#
#      Korean Name Director                         Video       Type Release
# ...

# %% [markdown]
# ## Analisis EDA

# %% [markdown]
# **1. Tendencia del Pop Koreano a lo largo de los tiempos (desde 1992-2020)**

# %% [markdown]
# En este gráfico de lineas observamos un crecimiento sostenido de produccion de videos musicales en el KPOP desde sus comienzos en el 1992 hasta 2020 con el pico mas alto de produccion en 2019, en la grafica podemos observar la produccion de videos musicales debido al Covid.

# %%
Kpop_music_videos['Year'] = pd.to_datetime(Kpop_music_videos['Date']).dt.year
trend_df = Kpop_music_videos.groupby('Year').size().reset_index(name='Count')

plt.figure(figsize=(12, 6))
sns.lineplot(data=trend_df, x='Year', y='Count', marker='o')
plt.title('Evolución del K-POP a lo largo del tiempo (1992-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Videos', fontsize=12)
plt.grid(True)
plt.savefig('kpop_t')

# %% [markdown]
# **2. Éxito por género (grupos masculinos vs grupos femeninos)**

# %% [markdown]
# En este gráfico se puede observar la cantidad de grupos musicales activos haciendo una comparativa de grups musicales masculinos y femeninos. </br>
# Observarmos que hay ligeramnete una mayor  cantidad de grupos masculinos que grupos femeninos.

# %%
boy_groups_active = Kpop_idols_boys[Kpop_idols_boys['Active'] == 'Yes']
girl_groups_active = Kpop_idols_girls[Kpop_idols_girls['Active'] == 'Yes']

success_gender = pd.DataFrame({
    'Group Type': ['Boy Groups', 'Girl Groups'],
    'Active Groups': [len(boy_groups_active), len(girl_groups_active)]
})

plt.figure(figsize=(8, 6))
sns.barplot(data=success_gender, x='Group Type', y='Active Groups', palette='coolwarm')
plt.title('Cantidad de grupos activos según el género', fontsize=14)
plt.xlabel('Group Type', fontsize=12)
plt.ylabel('Number of Groups', fontsize=12)
plt.savefig('success_by_gender.png')
plt.show()
# Out:
# <ipython-input-16-6fc9920d6fad>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=success_gender, x='Group Type', y='Active Groups', palette='coolwarm')

# %% [markdown]
# **3. Compañías líderes en la producción de grupos**

# %% [markdown]
# En esta tercera grafica, nos enseña las 10 principales compañias productoras de grupos Kpop segun el numero de grupos formados.</br> </br>
# A la cabeza de esta grafica conatmos con la productora musical SM SM Entertainment con 12 grupos. </br>
# Continuada de JYP Entertainment con 10 grupos y FNC en 3 lugar con 8 grupos. </br>
# Esta grafica tambien nos muestra una igualacion de 5 grupos musicales en 5 compañias.

# %%
all_groups_df = pd.concat([Kpop_idols_boys, Kpop_idols_girls], ignore_index=True)
top_companies = all_groups_df['Company'].value_counts().head(10).reset_index()
top_companies.columns = ['Company', 'Group Count']

plt.figure(figsize=(10, 6))
sns.barplot(data=top_companies, x='Group Count', y='Company', palette='viridis')
plt.title('Principales compañías productoras de grupos de K-POP', fontsize=14)
plt.xlabel('Number of Groups', fontsize=12)
plt.ylabel('Company', fontsize=12)
plt.savefig('top_companies.png')
plt.show()
# Out:
# <ipython-input-17-58be81e1d2dc>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_companies, x='Group Count', y='Company', palette='viridis')

# %% [markdown]
# **5. Relación entre el tamaño del grupo y el éxito**

# %% [markdown]
# En esta 4 grafica, hemos podido observar la dispersión de relacción entre el número de miembros originales y el estado de su actividad. </br>
# Los grupos que más miembros tienen suelen permanecer mas tiempo activos con lo cual suelen ser más populares ya que están más tiempo producciendo musica.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=all_groups_df, x='Members', y='Orig. Memb.', hue='Active', palette='muted')
plt.title('Tamaño del grupo vs. éxito', fontsize=14)
plt.xlabel('Current Members', fontsize=12)
plt.ylabel('Original Members', fontsize=12)
plt.legend(title='Active')
plt.savefig('group_size_vs_success.png')
plt.show()

# %% [markdown]
# **6. Predicción del éxito basada en características pasadas**

# %% [markdown]
# EN esta grafica vemos los grupos que tienen un potencial de exito, la comparativa se hizo con grupos de 5 a 7 miembros. </br>
# Con el tono oscuro observamos los grupos con mayor posibilidad de exito, dejando a DSP como el gupo mas exitoso. </br>
# En el color más claro los grupos con menor posibilidad de exito, estando en peor posicion el grupo Mafia.

# %%
# Ejemplo de insight: los grupos más exitosos suelen tener entre 5 y 7 miembros, pertenecer a ciertas compañías o haber debutadoen años específicos.
successful_groups = all_groups_df[(all_groups_df['Active'] == 'Yes') & (all_groups_df['Members'] >= 5) & (all_groups_df['Members'] <= 7)]
predicted_groups = all_groups_df[(all_groups_df['Members'] >= 5) & (all_groups_df['Members'] <= 7) & (~all_groups_df['Name'].isin(successful_groups['Name']))]

plt.figure(figsize=(10, 6))
sns.barplot(data=predicted_groups, x='Members', y='Company', palette='rocket')
plt.title('Grupos potencialmente exitosos (5-7 miembros)', fontsize=14)
plt.xlabel('Number of Members', fontsize=12)
plt.ylabel('Company', fontsize=12)
plt.savefig('predicted_success_groups.png')
plt.show()
# Out:
# <ipython-input-19-a0acbe9256f8>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=predicted_groups, x='Members', y='Company', palette='rocket')

# %% [markdown]
# **7. Composición de género en la industria**

# %% [markdown]
# En esta gráfica se muestra una distribución de genero en la industria del Kpop, eseñando una diferencia entre ambos generos. Siendo el genero masculino con mayor cantidad rozando casi los 700.

# %%
gender_distribution = Kpop_idols['Gender'].value_counts().reset_index()
gender_distribution.columns = ['Gender', 'Count']

plt.figure(figsize=(8, 6))
sns.barplot(data=gender_distribution, x='Gender', y='Count', palette='pastel')
plt.title('Distribución de género en la industria del K-POP', fontsize=14)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.savefig('gender_distribution.png')
plt.show()
# Out:
# <ipython-input-21-f6ff825e990e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_distribution, x='Gender', y='Count', palette='pastel')

# %% [markdown]
# **Grupos para hacer el festival de verano.**

# %%
active_groups = all_groups_df[all_groups_df['Active'] == 'Yes']

top_5_groups = active_groups.sort_values(by='Members', ascending=False).head(5)[['Name', 'Company', 'Members']]

top_5_groups.reset_index(drop=True)
# Out:
#         Name   Company  Members
# 0        NCT        SM       18
# 1        14U        BG       14
# 2  Seventeen    Pledis       13
# 3       WJSN  Starship       13
# 4   The Boyz   Cre.Ker       12

# %% [markdown]
# Para saber que grupos podrían tener mas pospularidad en un festival de verano, escogimos los gupos musicales que mas mimbros tenian y los mas populares son actualmente.

# %% [markdown]
# **Grafica 5 Grupos para hacer el festival de verano.**

# %% [markdown]
# En esta ultima grafica, vemos que la poupularidad que tendria los grupos escogidos para el festival de verano estan bastante equiparados. Destacando auque por muy poco el grupo NCT con un 25.7%, el grupo que podria tener menos visitantes en el festival es el grupo The Boyz con un 17.1%.

# %%
plt.figure(figsize=(8, 8))
plt.pie(
    top_5_groups['Members'],
    labels=top_5_groups['Name'],
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette("pastel")
)
plt.title('TOP 5 grupos para un festival de verano', fontsize=14)
plt.savefig('top_5_groups_pie_chart.png')
plt.show()

# %%
# !pip install nbconvert

from google.colab import files
# !jupyter nbconvert --to pdf "K_POP_Desafio.ipynb"
files.download("K_POP_Desafio.pdf")
# Out:
# ...
# [NbConvertApp] WARNING | pattern 'K_POP_Desafio.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...
